# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# Fuzzy string matching or searching is a process of approximating strings that matches a particular pattern.
#
# **Note** that it gives an approximate and there is no guarantee that the string can be exact, however, sometimes the string accurately matches the pattern. How close the string is to a given match is measured by the edit distance.
#
# FuzzyWuzzy uses [Levenshtein Distance](https://en.wikipedia.org/wiki/Levenshtein_distance) to calculate the edit distance.

# %% [markdown]
# Source Links
# - https://galaxydatatech.com/2017/12/31/fuzzy-string-matching-pandas-fuzzywuzzy/
# - https://medium.com/@rtjeannier/combining-data-sets-with-fuzzy-matching-17efcb510ab2
# - https://www.kaggle.com/rtatman/data-cleaning-challenge-inconsistent-data-entry

# %% [markdown]
# #### Simple Ratio

# %%
fuzz.ratio("Hello world", "Hello world!")
# Out:
# 96

# %% [markdown]
# #### Partial Ratio

# %%
fuzz.partial_ratio("Hello world", "Hello world!")
# Out:
# 100

# %% [markdown]
# #### Process
# **Extract and ExtractOne**

# %%
# extract strings from a list of choices
choices = ["Hello world is an introductory phrase in programming", 
           "Game of throne is a movie", 
           "Albert Einstein developed the theory of relativity", 
           "Asia is the largest continent in the world"]
 
process.extract("Hello world", choices, limit=2)
process.extractOne("Hello world", choices)
# Out:
# [('Hello world is an introductory phrase in programming', 90),
#  ('Asia is the largest continent in the world', 86)]
# ('Hello world is an introductory phrase in programming', 90)

# %%
choices = ["Atlanta Falcons", "New York Jets", "New York Giants", "Dallas Cowboys"]

# extract top 2 matches
process.extract("new york jets", choices, limit=2)

# extract best
process.extractOne("cowboys", choices)
process.extractOne("new york jets", choices)
# Out:
# [('New York Jets', 100), ('New York Giants', 79)]
# ('Dallas Cowboys', 90)
# ('New York Jets', 100)

# %% [markdown]
# #### Working with Pandas

# %%
# correct country names
correct_names = pd.read_csv('country-names.csv',encoding="ISO-8859-1")
# correct_names = correct_names['name'].dropna()
correct_names.head()
# Out:
#             name
# 0  Åland Islands
# 1        Albania
# 2        Andorra
# 3        Austria
# 4        Belarus

# %%
#Wrong country names dataset
wrong_names = pd.read_csv("wrong-country-names.csv",encoding="ISO-8859-1")
wrong_names.head()
# Out:
#             name alpha-2 alpha-3  country-code     iso_3166-2  region  \
# 0  Ålend Islends      AX     ALA           248  ISO 3166-2:AX  Europe
# 1        elbenie      AL     ALB             8  ISO 3166-2:AL  Europe
# 2        endorre      AD     AND            20  ISO 3166-2:AD  Europe
# 3        eustrie      AT     AUT            40  ISO 3166-2:AT  Europe
# 4        Belerus      BY     BLR           112  ISO 3166-2:BY  Europe
#
#         sub-region  region-code  sub-region-code
# 0  Northern Europe        150.0            154.0
# 1  Southern Europe        150.0             39.0
# 2  Southern Europe        150.0             39.0
# 3   Western Europe        150.0            155.0
# 4   Eastern Europe        150.0            151.0

# %%
# Defining function to get the right score and matches
def match_name(namedf, names_list, min_score=0):
    # -1 score incase we don't get any matches
    max_score = -1
    # Returning empty name for no match as well
    max_name = ""
    # Iternating over all names in the correct list
    for name2 in names_list:
        #Finding fuzzy match score
        score = fuzz.ratio(namedf['name'], name2)
        # Checking if we are above our threshold and have a better score
        if (score > min_score) & (score > max_score):
            max_name = name2
            max_score = score
    return max_name, max_score

# %%
# creating two columns
# most_matching_name -> whichever had the max score
# score -> the ratio score observed

wrong_names['most_matching_name'], wrong_names['score'] = zip(*wrong_names.apply(lambda x: match_name(x, correct_names['name'],0), axis=1))

# %%
wrong_names[['name','most_matching_name','score']]
# Out:
#                                              name  \
# 0                                   Ålend Islends
# 1                                         elbenie
# 2                                         endorre
# 3                                         eustrie
# 4                                         Belerus
# 5                                         Belgium
# 6                          Bosnie end Herzegovine
# 7                                        Bulgerie
# 8                                         Croetie
# 9                                  Czech Republic
# 10                                        Denmerk
# 11                                        Estonie
# 12                                  Feroe Islends
# 13                                        Finlend
# 14                                         Frence
# 15                                        Germeny
# 16                                      Gibrelter
# 17                                         Greece
# 18                                       Guernsey
# 19                                       Holy See
# 20                                        Hungery
# 21                                        Icelend
# 22                                        Irelend
# 23                                    Isle of Men
# 24                                          Itely
# 25                                         Jersey
# 26                                         Letvie
# 27                                  Liechtenstein
# 28                                      Lithuenie
# 29                                     Luxembourg
# ..                                            ...
# 219                                         Niger
# 220                                       Nigerie
# 221                                       Réunion
# 222                                        Rwende
# 223  Seint Helene, escension end Tristen de Cunhe
# 224                         Seo Tome end Principe
# 225                                       Senegel
# 226                                    Seychelles
# 227                                  Sierre Leone
# 228                                       Somelie
# 229                                  South efrice
# 230                                   South Suden
# 231                                         Suden
# 232                                     Swezilend
# 233                  Tenzenie, United Republic of
# 234                                          Togo
# 235                                       Tunisie
# 236                                        Ugende
# 237                                Western Sehere
# 238                                        Zembie
# 239                                      Zimbebwe
# 240                                    enterctice
# 241                                 Bouvet Islend
# 242                British Indien Oceen Territory
# 243                              Christmes Islend
# 244                       Cocos (Keeling) Islends
# 245                   French Southern Territories
# 246             Heerd Islend end McDoneld Islends
# 247  South Georgie end the South Sendwich Islends
# 248          United Stetes Minor Outlying Islends
#
#                                most_matching_name  score
# 0                                   Åland Islands     85
# 1                                         Albania     57
# 2                                         Andorra     71
# 3                                         Austria     71
# 4                                         Belarus     86
# 5                                         Belgium    100
# 6                          Bosnia and Herzegovina     86
# 7                                        Bulgaria     75
# 8                                         Croatia     71
# 9                                  Czech Republic    100
# 10                                        Denmark     86
# 11                                        Estonia     86
# 12                                  Faroe Islands     85
# 13                                        Finland     86
# 14                                         France     83
# 15                                        Germany     86
# 16                                      Gibraltar     78
# 17                                         Greece    100
# 18                                       Guernsey    100
# 19                                       Holy See    100
# 20                                        Hungary     86
# 21                                        Iceland     86
# 22                                        Ireland     86
# 23                                    Isle of Man     91
# 24                                          Italy     80
# 25                                         Jersey    100
# 26                                         Latvia     67
# 27                                  Liechtenstein    100
# 28                                      Lithuania     78
# 29                                     Luxembourg    100
# ..                                            ...    ...
# 219                                         Niger    100
# 220                                       Nigeria     86
# 221                                       Réunion    100
# 222                                        Sweden     67
# 223  Saint Helena, Ascension and Tristan da Cunha     84
# 224                         Sao Tome and Principe     90
# 225                                       Senegal     86
# 226                                    Seychelles    100
# 227                                  Sierra Leone     92
# 228                                       Somalia     71
# 229                                  South Africa     83
# 230                                   South Sudan     91
# 231                                         Sudan     80
# 232                                     Swaziland     78
# 233                  Tanzania, United Republic of     89
# 234                                          Togo    100
# 235                                       Tunisia     86
# 236                                        Uganda     67
# 237                                Western Sahara     79
# 238                                        Zambia     67
# 239                                      Zimbabwe     88
# 240                                    Antarctica     70
# 241                                 Bouvet Island     92
# 242                British Indian Ocean Territory     93
# 243                              Christmas Island     88
# 244                       Cocos (Keeling) Islands     96
# 245                   French Southern Territories    100
# 246             Heard Island and McDonald Islands     85
# 247  South Georgia and the South Sandwich Islands     91
# 248          United States Minor Outlying Islands     94
#
# [249 rows x 3 columns]
